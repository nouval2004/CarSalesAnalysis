# %% [markdown]
# # 1. Pernyataan Masalah
# * Dataset "car_price.csv" menyediakan informasi komprehensif tentang transaksi penjualan kendaraan. Data ini mencakup tahun pembuatan kendaraan, merek atau produsen kendaraan, model spesifik kendaraan, versi atau paket opsi tertentu dari model, jenis bodi kendaraan, jenis transmisi kendaraan, Nomor Identifikasi Kendaraan, negara bagian tempat kendaraan terdaftar, penilaian kondisi kendaraan, jarak tempuh kendaraan, warna eksterior kendaraan, warna interior kendaraan, entitas atau perusahaan yang menjual kendaraan, nilai Manheim Market Report, harga jual kendaraan, serta tanggal dan waktu penjualan kendaraan.
#
# * Proyek ini dibuat untuk menganalisis data penjualan kendaraan guna memahami pola dan faktor-faktor yang mempengaruhi harga jual serta tren pasar. Dengan meningkatnya persaingan di pasar otomotif, memahami dinamika ini menjadi sangat penting untuk Mengidentifikasi tren penjualan dari tahun ke tahun,Menentukan faktor-faktor yang mempengaruhi harga jual kendaraan,Mengenali merek dan jenis bodi kendaraan yang paling populer dan paling mahal,Mengembangkan strategi pemasaran dan penjualan yang lebih efektif.
#
# * Pertanyaan-pertanyaan spesifik yang akan dibahas meliputi: Mengidentifikasi tren penjualan dari tahun ke tahun, Menentukan faktor-faktor yang mempengaruhi harga jual kendaraan, Mengenali merek dan jenis bodi kendaraan yang paling populer dan paling mahal, Mengembangkan strategi pemasaran dan penjualan yang lebih efektif.
#
# * Dengan menjawab pertanyaan-pertanyaan di atas, analisis ini akan memberikan kontribusi signifikan pada strategi penjualan dan pemasaran kendaraan. Pertama, mengidentifikasi tren pasar akan membantu perusahaan memahami bagaimana penjualan kendaraan berubah dari tahun ke tahun, yang sangat penting untuk perencanaan jangka panjang dan penyesuaian strategi pemasaran agar sesuai dengan tren pasar. Kedua, menentukan faktor-faktor utama yang mempengaruhi harga jual kendaraan memungkinkan perusahaan untuk mengoptimalkan harga jual berdasarkan kondisi pasar dan karakteristik kendaraan, sehingga dapat meningkatkan profitabilitas. Ketiga, mengetahui merek dan tipe bodi kendaraan yang memiliki harga jual tertinggi membantu perusahaan menyesuaikan inventaris dan strategi penjualan untuk memaksimalkan keuntungan. Terakhir, mengidentifikasi merek dan tipe bodi kendaraan yang paling populer membantu dalam pengelolaan stok dan penyesuaian penawaran produk untuk memenuhi permintaan pasar. Analisis ini akan memberikan wawasan yang mendalam untuk mendukung pengambilan keputusan yang lebih baik dalam strategi penjualan dan pemasaran kendaraan.
#
# # 2. Asumsi
# * Kelengkapan data: Mengasumsikan bahwa dataset tidak memiliki banyak nilai yang hilang atau kosong untuk kolom-kolom penting seperti tahun, merek, model, harga jual, dan tanggal penjualan.
#
# * Akurasi data: Mengasumsikan bahwa data yang disediakan akurat dan konsisten, terutama untuk variabel numerik seperti harga jual, odometer, dan nilai MMR.
#
# * Independensi observasi: Mengasumsikan bahwa setiap baris data (penjualan kendaraan) independen dan tidak berkaitan dengan observasi lain dalam dataset.
#
# * Tidak adanya multikolinieritas: Mengasumsikan bahwa tidak ada korelasi kuat antara variabel prediktor seperti tahun, merek, model, jenis bodi, dan kondisi kendaraan.
#
# * Distribusi data numerik: Asumsi tentang distribusi data numerik seperti harga jual, odometer, dan nilai MMR. Misalnya, apakah data mengikuti distribusi normal atau distribusi lainnya.
#
# # 3. Pertanyaan Penelitian
# * Bagaimana pola evolusi tren penjualan kendaraan dari tahun ke tahun? Apakah ada lonjakan atau penurunan dramatis yang bisa diidentifikasi, serta faktor-faktor utama yang mungkin mempengaruhinya?
#
# * Apa yang menjadi pemicu fluktuasi dalam harga jual kendaraan? Selain faktor-faktor umum seperti kondisi kendaraan dan model, apakah ada variabel-variabel tidak terduga yang secara signifikan memengaruhi harga jual?
#
# * Bagaimana merek dan jenis bodi kendaraan tertentu mempengaruhi dinamika pasar dengan mengeksplorasi 10 merek mobil dan jenis bodi yang secara konsisten mempertahankan harga jual tertinggi?
#
# * Dengan memperhatikan preferensi konsumen dan tren pasar, merek dan jenis bodi kendaraan apa yang paling diminati dan paling berhasil dalam distribusi, dan bagaimana hal ini mempengaruhi strategi pemasaran dan stok perusahaan?
#
# # 4. Execution

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('car_prices.csv')
df.head()
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# ...

# %%
df.shape
# Out:
# (558837, 16)

# %%
df.columns
# Out:
# Index(['year', 'make', 'model', 'trim', 'body', 'transmission', 'vin', 'state',
#        'condition', 'odometer', 'color', 'interior', 'seller', 'mmr',
#        'sellingprice', 'saledate'],
#       dtype='object')

# %%
df.duplicated().any()
# Out:
# False

# %% [markdown]
#  **Penanganan Nilai Kosong pada Kolom**

# %%
df.isnull().sum()
# Out:
# year                0
# make            10301
# model           10399
# trim            10651
# body            13195
# transmission    65352
# vin                 4
# state               0
# condition       11820
# odometer           94
# color             749
# interior          749
# seller              0
# mmr                38
# sellingprice       12
# saledate           12
# dtype: int64

# %%
df['make'] = df['make'].fillna('Other')
df['model'] = df['model'].fillna('Other')
df['trim'] = df['trim'].fillna('Other')
df['color'] = df['color'].fillna('Other')

# %%
df['body'] = df['body'].fillna(df['body'].mode()[0])
df['transmission'] = df['transmission'].fillna(df['transmission'].mode()[0])
df['interior'] = df['interior'].fillna(df['interior'].mode()[0])

# %%
df.dropna(subset=['vin'], inplace=True)
df.dropna(subset=['saledate'], inplace=True)

# %%
df.isnull().sum()
# Out:
# year                0
# make                0
# model               0
# trim                0
# body                0
# transmission        0
# vin                 0
# state               0
# condition       11816
# odometer           94
# color               0
# interior            0
# seller              0
# mmr                22
# sellingprice        0
# saledate            0
# dtype: int64

# %%
df['condition'].fillna(df['condition'].median(), inplace=True)
df['odometer'].fillna(df['odometer'].mean(), inplace=True)
df['mmr'].fillna(df['mmr'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# year            0
# make            0
# model           0
# trim            0
# body            0
# transmission    0
# vin             0
# state           0
# condition       0
# odometer        0
# color           0
# interior        0
# seller          0
# mmr             0
# sellingprice    0
# saledate        0
# dtype: int64

# %% [markdown]
# ### Pertanyaan Penelitian
# 1. Bagaimana pola evolusi tren penjualan kendaraan dari tahun ke tahun? Apakah ada lonjakan atau penurunan dramatis yang bisa diidentifikasi, serta faktor-faktor utama yang mungkin mempengaruhinya?

# %%
sales_per_year = df.groupby('year').size()

plt.figure(figsize=(10, 6))
sales_per_year.plot(kind='line')
plt.title('Vehicle Sales Trend by Year')
plt.xlabel('Year')
plt.ylabel('Number of Vehicles Sold')
plt.show()

# %%
mask = (df['year'] >= 2005) & (df['year'] <= 2015)
filtered_df = df[mask]

# %%
year_counts = filtered_df['year'].value_counts().sort_index()

plt.figure(figsize=(10, 6))
year_counts.plot(kind='bar')
plt.title('Bar Chart: Year (2005-2015)')
plt.xlabel('year')
plt.ylabel('Number of Vehicles')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 2. Apa yang menjadi pemicu terjadinya naik dan turun nya harga jual kendaraan? Selain faktor-faktor umum seperti kondisi kendaraan dan model, apakah ada variabel-variabel lain yang memengaruhi harga jual?

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='condition', y='sellingprice', data=df)
plt.title('Condition vs Selling Price')
plt.show()

plt.figure(figsize=(10, 6))
sns.scatterplot(x='odometer', y='sellingprice', data=df)
plt.title('Odometer vs Selling Price')
plt.show()

plt.figure(figsize=(10, 6))
sns.scatterplot(x='mmr', y='sellingprice', data=df)
plt.title('MMR vs Selling Price')
plt.show()

# %%
sns.pairplot(df, x_vars=['odometer', 'condition', 'mmr'], y_vars='sellingprice', height=5, aspect=0.7, kind='scatter')
plt.title('Factors Affecting Selling Price')
plt.show()

# %% [markdown]
# 3. Bagaimana merek dan jenis bodi kendaraan tertentu mempengaruhi dinamika pasar dengan mengeksplorasi merek mobil dan jenis bodi yang secara konsisten mempertahankan harga jual tertinggi?

# %%
average_price_per_make = df.groupby('make')['sellingprice'].mean()
sorted_average_price = average_price_per_make.sort_values(ascending=False)
top_10_makes = sorted_average_price.head(10)

print(top_10_makes)
# Out:
# make
# Rolls-Royce     153488.235294
# Ferrari         127210.526316
# Lamborghini     112625.000000
# Bentley          74367.672414
# airstream        71000.000000
# Tesla            67054.347826
# Aston Martin     54812.000000
# Fisker           46461.111111
# Maserati         45320.300752
# Lotus            40800.000000
# Name: sellingprice, dtype: float64

# %%
average_price_per_make = df.groupby('body')['sellingprice'].mean()
sorted_average_price = average_price_per_make.sort_values(ascending=False)
top_10_body = sorted_average_price.head(10)

print(top_10_body)
# Out:
# body
# granturismo convertible    79041.666667
# GranTurismo Convertible    74000.000000
# CTS-V Wagon                50500.000000
# cts-v coupe                39707.142857
# CTS-V Coupe                38425.750000
# Q60 Convertible            36667.105263
# q60 convertible            35725.000000
# q60 coupe                  31112.500000
# Q60 Coupe                  29479.687500
# mega cab                   29055.769231
# Name: sellingprice, dtype: float64

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x=top_10_makes.index, y=top_10_makes.values, palette='husl')
plt.title('Top 10 Brands with the Highest Average Selling Price')
plt.xlabel('Merk')
plt.ylabel('Average Selling Price')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x=top_10_body.index, y=top_10_body.values, palette='husl')
plt.title('Top 10 body with the Highest Average Selling Price')
plt.xlabel('body')
plt.ylabel('Average Selling Price')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 4. Dengan memperhatikan preferensi konsumen dan tren pasar, merek dan jenis bodi kendaraan apa yang paling diminati dan paling berhasil dalam distribusi, dan bagaimana hal ini mempengaruhi strategi pemasaran dan stok perusahaan?

# %%
brand_distribution = df['make'].value_counts().head(10) 
body_distribution = df['body'].value_counts().head(10)  

print("merek yang paling sering muncul", brand_distribution)
print("tipe yang paling sering muncul", body_distribution)
# Out:
# merek yang paling sering muncul make
# Ford         93553
# Chevrolet    60197
# Nissan       53946
# Toyota       39871
# Dodge        30708
# Honda        27206
# Hyundai      21811
# BMW          20719
# Kia          18075
# Chrysler     17274
# Name: count, dtype: int64
# tipe yang paling sering muncul body
# Sedan          212624
# SUV            119292
# sedan           41903
# suv             24552
# Hatchback       21380
# Minivan         21363
# Coupe           14602
# Wagon           13629
# Crew Cab        13280
# Convertible      8652
# Name: count, dtype: int64

# %%
plt.figure(figsize=(20, 8))
sns.barplot(x=brand_distribution.index, y=brand_distribution.values, palette='husl')
plt.title('top 10 best selling car brands')
plt.xlabel('brands')
plt.ylabel('count')
plt.xticks(rotation=90, ha='right')
plt.show()

# %%
plt.figure(figsize=(20, 8))
sns.barplot(x=body_distribution.index, y=body_distribution.values, palette='husl')
plt.title('top 10 best selling cars body type')
plt.xlabel('body type')
plt.ylabel('count')
plt.xticks(rotation=90, ha='right')
plt.show()

# %% [markdown]
# # 5. Hasil
#
# * Pola evolusi tren penjualan kendaraan menunjukkan peningkatan yang stabil dari tahun 1983 hingga mencapai puncaknya pada tahun 2012. Setelah itu, terjadi sedikit penurunan hingga tahun 2014, diikuti oleh penurunan signifikan pada tahun 2015. Lonjakan tertinggi terjadi pada tahun 2012, sementara penurunan dramatis terjadi pada tahun 2015. Faktor-faktor utama yang mungkin mempengaruhi tren ini termasuk perubahan dalam ekonomi global, kebijakan industri otomotif, inovasi teknologi, dan perubahan preferensi konsumen terhadap kendaraan.
#
# * Analisis scatter plot menunjukkan adanya korelasi positif antara kondisi kendaraan dan harga jual, di mana kondisi yang lebih baik cenderung menghasilkan harga jual yang lebih tinggi, meskipun hubungan ini tidak sepenuhnya linier dan terdapat variasi yang signifikan pada setiap tingkat kondisi; pola data membentuk segitiga dengan rentang harga lebih sempit pada kondisi rendah dan lebih lebar pada kondisi tinggi, serta beberapa outlier mengindikasikan bahwa faktor-faktor lain seperti merek, model, dan fitur juga memainkan peran penting dalam menentukan harga jual kendaraan.
#
# * Scatter plot ini menunjukkan korelasi positif yang kuat antara nilai MMR (Manheim Market Report) dan harga jual kendaraan, dengan pola data menyerupai garis lurus dari kiri bawah ke kanan atas, mengindikasikan hubungan linier yang kuat. Meskipun sebagian besar data terkonsentrasi pada nilai MMR antara 20.000 hingga 80.000, terdapat outlier yang menunjukkan variasi signifikan, terutama pada nilai MMR yang lebih tinggi. Hal ini menandakan bahwa meskipun MMR adalah indikator penting dalam menentukan harga jual kendaraan, faktor-faktor lain seperti merek, model, kondisi, dan fitur khusus juga mempengaruhi harga jual secara signifikan.
#
# * Scatter plot ini menunjukkan korelasi negatif yang kuat antara jarak tempuh odometer dan harga jual kendaraan, di mana semakin tinggi jarak tempuh suatu kendaraan, semakin rendah harga jualnya, dan sebaliknya, semakin rendah jarak tempuh, semakin tinggi harga jualnya. Pola data mengindikasikan bahwa jarak tempuh odometer merupakan indikator penting dalam menentukan harga jual kendaraan, dengan hubungan yang cukup erat antara kedua variabel ini, mencerminkan bahwa konsumen cenderung menghargai kendaraan dengan jarak tempuh yang lebih rendah.
#
# * Analisis pasar menunjukkan bahwa merek-merek prestisius seperti Rolls-Royce, Ferrari, dan Lamborghini secara konsisten mempertahankan harga jual tertinggi, mencerminkan kepercayaan konsumen pada kualitas dan eksklusivitas merek tersebut, sementara jenis bodi seperti granturismo convertible mendominasi segmen harga tinggi, menunjukkan preferensi pasar terhadap kendaraan dengan gaya konvertibel yang elegan dan mewah.
#
# * Analisis data menunjukkan bahwa Ford memimpin penjualan mobil dengan jumlah lebih dari 80.000 unit, diikuti oleh Chevrolet, Nissan, dan Toyota. Sementara itu, jenis bodi Sedan mendominasi pasar dengan penjualan lebih dari 200.000 unit, diikuti oleh SUV, Hatchback, dan MPV. Grafik-gambar ini memberikan perbandingan yang jelas mengenai penjualan mobil berdasarkan merek dan jenis bodi terlaris, yang memberikan wawasan yang berharga bagi analisis pasar dan perencanaan strategi pemasaran di industri otomotif.
#
#
# # 6.Saran
#
# * Perhatian terhadap kondisi kendaraan sangat penting karena memiliki dampak yang signifikan pada harga jual. Merawat kendaraan secara rutin dan memastikan kondisinya tetap optimal tidak hanya akan meningkatkan nilai jualnya, tetapi juga akan menarik minat calon pembeli potensial. Melakukan perawatan yang teratur seperti servis berkala, perbaikan secara tepat waktu, dan menjaga kebersihan kendaraan akan menciptakan kesan yang positif pada pembeli. Selain itu, mempertimbangkan untuk melakukan perawatan kosmetik seperti detailing interior dan eksterior dapat memberikan tampilan yang lebih menarik dan membuat kendaraan terlihat lebih terawat. Dengan demikian, investasi dalam perawatan kendaraan tidak hanya akan membantu meningkatkan nilai jualnya, tetapi juga dapat meningkatkan daya tariknya di pasar dan mempercepat proses penjualan.
#
# * Penjual mobil sebaiknya lebih fokus pada merek-merek yang populer dan jenis tipe mobil yang diminati pasar. Analisis data menunjukkan bahwa merek-merek seperti Ford, Chevrolet, Nissan, dan Toyota memiliki penjualan yang tinggi, sementara jenis bodi Sedan, SUV, Hatchback, dan MPV mendominasi pasar. Oleh karena itu, penjual dapat memprioritaskan merek-merek dan jenis bodi ini dalam strategi pemasaran dan stok mereka. Hal ini dapat meningkatkan peluang penjualan dan memaksimalkan profitabilitas, karena konsumen cenderung lebih tertarik pada merek-merek dan jenis bodi yang sudah terbukti populer dan diminati di pasar.
#
# * Perhatikan Nilai MMR: Memahami nilai MMR (Manheim Market Report) dapat membantu dalam menetapkan harga jual yang realistis dan kompetitif. Tetap mengikuti perubahan dalam nilai MMR dan memperbarui harga jual secara berkala sesuai dengan perubahan pasar dapat meningkatkan peluang penjualan.
